# %%
#Import Required Libraries

import numpy as np  #to handle arrays and photo pixels
import matplotlib.pyplot as plt  #data visualization tool
import seaborn as sns  #statistical plotting 
import pandas as pd #data manipulation

# %matplotlib inline

# %%
#Load Dataset

#select columns

columns = ['SepalLengthCm','SepalWidthCm', 'PetalLengthCm','PetalWidthCm','Species']

#load the data
#data = sns.load_dataset("Iris") 
df = pd.read_csv('Iris.csv')

df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# draw lineplot 
#data = pd.read_csv('Iris.csv',names = columns)
sns.lineplot(x="SepalLengthCm", y="SepalWidthCm", data=df)

  
# setting the title using Matplotlib
plt.title('Sepal Length v/s Sepal Width')
# Out:
# Text(0.5, 1.0, 'Sepal Length v/s Sepal Width')

# %%
df.describe()  #description of dataset
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#Visualize the whole dataset
x_vars = ["SepalLengthCm", "SepalWidthCm"]
y_vars = ["PetalLengthCm", "PetalWidthCm"]
sns.set(style="ticks")
sns.pairplot(df, hue='Species', x_vars=x_vars, y_vars=y_vars, height=4, aspect=1.5)
plt.show()

# %%
# Drop the first row, which contains non-numeric labels
df = df.iloc[1:, :]

# Convert the remaining data to NumPy arrays
data = df.values
X = data[:, 0:4].astype(float)  # Features (sepal length, sepal width, petal length, petal width)
Y = data[:, 4].astype(float)    # Target variable (species labels)
print(X)
print(Y)
# Out:
# [[  2.    4.9   3.    1.4]
#  [  3.    4.7   3.2   1.3]
#  [  4.    4.6   3.1   1.5]
#  [  5.    5.    3.6   1.4]
#  [  6.    5.4   3.9   1.7]
#  [  7.    4.6   3.4   1.4]
#  [  8.    5.    3.4   1.5]
#  [  9.    4.4   2.9   1.4]
#  [ 10.    4.9   3.1   1.5]
#  [ 11.    5.4   3.7   1.5]
#  [ 12.    4.8   3.4   1.6]
#  [ 13.    4.8   3.    1.4]
#  [ 14.    4.3   3.    1.1]
#  [ 15.    5.8   4.    1.2]
#  [ 16.    5.7   4.4   1.5]
#  [ 17.    5.4   3.9   1.3]
#  [ 18.    5.1   3.5   1.4]
#  [ 19.    5.7   3.8   1.7]
#  [ 20.    5.1   3.8   1.5]
#  [ 21.    5.4   3.4   1.7]
#  [ 22.    5.1   3.7   1.5]
#  [ 23.    4.6   3.6   1. ]
#  [ 24.    5.1   3.3   1.7]
#  [ 25.    4.8   3.4   1.9]
#  [ 26.    5.    3.    1.6]
#  [ 27.    5.    3.4   1.6]
#  [ 28.    5.2   3.5   1.5]
#  [ 29.    5.2   3.4   1.4]
#  [ 30.    4.7   3.2   1.6]
#  [ 31.    4.8   3.1   1.6]
#  [ 32.    5.4   3.4   1.5]
#  [ 33.    5.2   4.1   1.5]
#  [ 34.    5.5   4.2   1.4]
#  [ 35.    4.9   3.1   1.5]
#  [ 36.    5.    3.2   1.2]
#  [ 37.    5.5   3.5   1.3]
#  [ 38.    4.9   3.1   1.5]
#  [ 39.    4.4   3.    1.3]
#  [ 40.    5.1   3.4   1.5]
#  [ 41.    5.    3.5   1.3]
#  [ 42.    4.5   2.3   1.3]
#  [ 43.    4.4   3.2   1.3]
#  [ 44.    5.    3.5   1.6]
#  [ 45.    5.1   3.8   1.9]
#  [ 46.    4.8   3.    1.4]
#  [ 47.    5.1   3.8   1.6]
#  [ 48.    4.6   3.2   1.4]
#  [ 49.    5.3   3.7   1.5]
#  [ 50.    5.    3.3   1.4]
#  [ 51.    7.    3.2   4.7]
#  [ 52.    6.4   3.2   4.5]
#  [ 53.    6.9   3.1   4.9]
#  [ 54.    5.5   2.3   4. ]
#  [ 55.    6.5   2.8   4.6]
#  [ 56.    5.7   2.8   4.5]
#  [ 57.    6.3   3.3   4.7]
#  [ 58.    4.9   2.4   3.3]
#  [ 59.    6.6   2.9   4.6]
#  [ 60.    5.2   2.7   3.9]
#  [ 61.    5.    2.    3.5]
#  [ 62.    5.9   3.    4.2]
#  [ 63.    6.    2.2   4. ]
#  [ 64.    6.1   2.9   4.7]
#  [ 65.    5.6   2.9   3.6]
#  [ 66.    6.7   3.1   4.4]
#  [ 67.    5.6   3.    4.5]
#  [ 68.    5.8   2.7   4.1]
#  [ 69.    6.2   2.2   4.5]
#  [ 70.    5.6   2.5   3.9]
#  [ 71.    5.9   3.2   4.8]
#  [ 72.    6.1   2.8   4. ]
#  [ 73.    6.3   2.5   4.9]
#  [ 74.    6.1   2.8   4.7]
#  [ 75.    6.4   2.9   4.3]
#  [ 76.    6.6   3.    4.4]
#  [ 77.    6.8   2.8   4.8]
#  [ 78.    6.7   3.    5. ]
#  [ 79.    6.    2.9   4.5]
#  [ 80.    5.7   2.6   3.5]
#  [ 81.    5.5   2.4   3.8]
#  [ 82.    5.5   2.4   3.7]
#  [ 83.    5.8   2.7   3.9]
#  [ 84.    6.    2.7   5.1]
#  [ 85.    5.4   3.    4.5]
#  [ 86.    6.    3.4   4.5]
#  [ 87.    6.7   3.1   4.7]
#  [ 88.    6.3   2.3   4.4]
#  [ 89.    5.6   3.    4.1]
#  [ 90.    5.5   2.5   4. ]
#  [ 91.    5.5   2.6   4.4]
#  [ 92.    6.1   3.    4.6]
#  [ 93.    5.8   2.6   4. ]
#  [ 94.    5.    2.3   3.3]
#  [ 95.    5.6   2.7   4.2]
#  [ 96.    5.7   3.    4.2]
#  [ 97.    5.7   2.9   4.2]
#  [ 98.    6.2   2.9   4.3]
#  [ 99.    5.1   2.5   3. ]
#  [100.    5.7   2.8   4.1]
#  [101.    6.3   3.3   6. ]
#  [102.    5.8   2.7   5.1]
#  [103.    7.1   3.    5.9]
#  [104.    6.3   2.9   5.6]
#  [105.    6.5   3.    5.8]
#  [106.    7.6   3.    6.6]
#  [107.    4.9   2.5   4.5]
#  [108.    7.3   2.9   6.3]
#  [109.    6.7   2.5   5.8]
#  [110.    7.2   3.6   6.1]
#  [111.    6.5   3.2   5.1]
#  [112.    6.4   2.7   5.3]
#  [113.    6.8   3.    5.5]
#  [114.    5.7   2.5   5. ]
#  [115.    5.8   2.8   5.1]
#  [116.    6.4   3.2   5.3]
#  [117.    6.5   3.    5.5]
#  [118.    7.7   3.8   6.7]
#  [119.    7.7   2.6   6.9]
#  [120.    6.    2.2   5. ]
#  [121.    6.9   3.2   5.7]
#  [122.    5.6   2.8   4.9]
#  [123.    7.7   2.8   6.7]
#  [124.    6.3   2.7   4.9]
#  [125.    6.7   3.3   5.7]
#  [126.    7.2   3.2   6. ]
#  [127.    6.2   2.8   4.8]
#  [128.    6.1   3.    4.9]
#  [129.    6.4   2.8   5.6]
#  [130.    7.2   3.    5.8]
#  [131.    7.4   2.8   6.1]
#  [132.    7.9   3.8   6.4]
#  [133.    6.4   2.8   5.6]
#  [134.    6.3   2.8   5.1]
#  [135.    6.1   2.6   5.6]
#  [136.    7.7   3.    6.1]
#  [137.    6.3   3.4   5.6]
#  [138.    6.4   3.1   5.5]
#  [139.    6.    3.    4.8]
#  [140.    6.9   3.1   5.4]
#  [141.    6.7   3.1   5.6]
#  [142.    6.9   3.1   5.1]
#  [143.    5.8   2.7   5.1]
#  [144.    6.8   3.2   5.9]
#  [145.    6.7   3.3   5.7]
#  [146.    6.7   3.    5.2]
#  [147.    6.3   2.5   5. ]
#  [148.    6.5   3.    5.2]
#  [149.    6.2   3.4   5.4]
#  [150.    5.9   3.    5.1]]
# [0.2 0.2 0.2 0.2 0.4 0.3 0.2 0.2 0.1 0.2 0.2 0.1 0.1 0.2 0.4 0.4 0.3 0.3
#  0.3 0.2 0.4 0.2 0.5 0.2 0.2 0.4 0.2 0.2 0.2 0.2 0.4 0.1 0.2 0.1 0.2 0.2
#  0.1 0.2 0.2 0.3 0.3 0.2 0.6 0.4 0.3 0.2 0.2 0.2 0.2 1.4 1.5 1.5 1.3 1.5
#  1.3 1.6 1.  1.3 1.4 1.  1.5 1.  1.4 1.3 1.4 1.5 1.  1.5 1.1 1.8 1.3 1.5
#  1.2 1.3 1.4 1.4 1.7 1.5 1.  1.1 1.  1.2 1.6 1.5 1.6 1.5 1.3 1.3 1.3 1.2
#  1.4 1.2 1.  1.3 1.2 1.3 1.3 1.1 1.3 2.5 1.9 2.1 1.8 2.2 2.1 1.7 1.8 1.8
#  2.5 2.  1.9 2.1 2.  2.4 2.3 1.8 2.2 2.3 1.5 2.3 2.  2.  1.8 2.1 1.8 1.8
#  1.8 2.1 1.6 1.9 2.  2.2 1.5 1.4 2.3 2.4 1.8 1.8 2.1 2.4 2.3 1.9 2.3 2.5
#  2.3 1.9 2.  2.3 1.8]

# %%
# # Calculate average of each features for all classes
# Y_Data = np.array([np.average(X[:, i][Y==j].astype('float32')) 
# for i in range (X.shape[1])
#     for j in (np.unique(Y))])
# Y_Data_reshaped = Y_Data.reshape(4, 3)
# Y_Data_reshaped = np.swapaxes(Y_Data_reshaped, 0, 1)
# X_axis = np.arange(len(columns)-1)
# width = 0.25

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(X,Y, test_size=0.2)
print(x_train)
# Out:
# [[110.    7.2   3.6   6.1]
#  [ 70.    5.6   2.5   3.9]
#  [ 93.    5.8   2.6   4. ]
#  [104.    6.3   2.9   5.6]
#  [ 24.    5.1   3.3   1.7]
#  [ 34.    5.5   4.2   1.4]
#  [134.    6.3   2.8   5.1]
#  [127.    6.2   2.8   4.8]
#  [ 76.    6.6   3.    4.4]
#  [109.    6.7   2.5   5.8]
#  [ 21.    5.4   3.4   1.7]
#  [106.    7.6   3.    6.6]
#  [ 73.    6.3   2.5   4.9]
#  [ 11.    5.4   3.7   1.5]
#  [ 60.    5.2   2.7   3.9]
#  [ 45.    5.1   3.8   1.9]
#  [ 99.    5.1   2.5   3. ]
#  [ 12.    4.8   3.4   1.6]
#  [ 85.    5.4   3.    4.5]
#  [ 13.    4.8   3.    1.4]
#  [140.    6.9   3.1   5.4]
#  [123.    7.7   2.8   6.7]
#  [ 62.    5.9   3.    4.2]
#  [ 19.    5.7   3.8   1.7]
#  [129.    6.4   2.8   5.6]
#  [ 46.    4.8   3.    1.4]
#  [115.    5.8   2.8   5.1]
#  [141.    6.7   3.1   5.6]
#  [145.    6.7   3.3   5.7]
#  [142.    6.9   3.1   5.1]
#  [ 63.    6.    2.2   4. ]
#  [ 22.    5.1   3.7   1.5]
#  [119.    7.7   2.6   6.9]
#  [ 79.    6.    2.9   4.5]
#  [ 98.    6.2   2.9   4.3]
#  [121.    6.9   3.2   5.7]
#  [150.    5.9   3.    5.1]
#  [ 31.    4.8   3.1   1.6]
#  [144.    6.8   3.2   5.9]
#  [ 58.    4.9   2.4   3.3]
#  [ 10.    4.9   3.1   1.5]
#  [ 83.    5.8   2.7   3.9]
#  [114.    5.7   2.5   5. ]
#  [ 88.    6.3   2.3   4.4]
#  [147.    6.3   2.5   5. ]
#  [112.    6.4   2.7   5.3]
#  [  8.    5.    3.4   1.5]
#  [ 47.    5.1   3.8   1.6]
#  [  7.    4.6   3.4   1.4]
#  [ 37.    5.5   3.5   1.3]
#  [ 87.    6.7   3.1   4.7]
#  [ 56.    5.7   2.8   4.5]
#  [ 30.    4.7   3.2   1.6]
#  [  2.    4.9   3.    1.4]
#  [ 57.    6.3   3.3   4.7]
#  [100.    5.7   2.8   4.1]
#  [107.    4.9   2.5   4.5]
#  [ 50.    5.    3.3   1.4]
#  [ 33.    5.2   4.1   1.5]
#  [ 48.    4.6   3.2   1.4]
#  [ 51.    7.    3.2   4.7]
#  [ 82.    5.5   2.4   3.7]
#  [ 74.    6.1   2.8   4.7]
#  [ 89.    5.6   3.    4.1]
#  [102.    5.8   2.7   5.1]
#  [  6.    5.4   3.9   1.7]
#  [  9.    4.4   2.9   1.4]
#  [ 36.    5.    3.2   1.2]
#  [ 80.    5.7   2.6   3.5]
#  [ 78.    6.7   3.    5. ]
#  [ 40.    5.1   3.4   1.5]
#  [ 67.    5.6   3.    4.5]
#  [ 41.    5.    3.5   1.3]
#  [128.    6.1   3.    4.9]
#  [113.    6.8   3.    5.5]
#  [ 18.    5.1   3.5   1.4]
#  [ 38.    4.9   3.1   1.5]
#  [126.    7.2   3.2   6. ]
#  [ 14.    4.3   3.    1.1]
#  [ 71.    5.9   3.2   4.8]
#  [  5.    5.    3.6   1.4]
#  [133.    6.4   2.8   5.6]
#  [146.    6.7   3.    5.2]
#  [ 32.    5.4   3.4   1.5]
#  [ 27.    5.    3.4   1.6]
#  [148.    6.5   3.    5.2]
#  [ 95.    5.6   2.7   4.2]
#  [ 42.    4.5   2.3   1.3]
#  [143.    5.8   2.7   5.1]
#  [ 29.    5.2   3.4   1.4]
#  [ 81.    5.5   2.4   3.8]
#  [105.    6.5   3.    5.8]
#  [ 94.    5.    2.3   3.3]
#  [149.    6.2   3.4   5.4]
#  [ 61.    5.    2.    3.5]
#  [131.    7.4   2.8   6.1]
#  [ 49.    5.3   3.7   1.5]
#  [ 96.    5.7   3.    4.2]
#  [ 17.    5.4   3.9   1.3]
#  [ 55.    6.5   2.8   4.6]
#  [ 15.    5.8   4.    1.2]
#  [ 92.    6.1   3.    4.6]
#  [ 64.    6.1   2.9   4.7]
#  [ 16.    5.7   4.4   1.5]
#  [116.    6.4   3.2   5.3]
#  [ 68.    5.8   2.7   4.1]
#  [136.    7.7   3.    6.1]
#  [ 54.    5.5   2.3   4. ]
#  [132.    7.9   3.8   6.4]
#  [124.    6.3   2.7   4.9]
#  [130.    7.2   3.    5.8]
#  [139.    6.    3.    4.8]
#  [ 20.    5.1   3.8   1.5]
#  [111.    6.5   3.2   5.1]
#  [135.    6.1   2.6   5.6]
#  [ 28.    5.2   3.5   1.5]
#  [122.    5.6   2.8   4.9]
#  [ 44.    5.    3.5   1.6]
#  [ 69.    6.2   2.2   4.5]]

# %%
print(y_train)
# Out:
# [2.5 1.1 1.2 1.8 0.5 0.2 1.5 1.8 1.4 1.8 0.2 2.1 1.5 0.2 1.4 0.4 1.1 0.2
#  1.5 0.1 2.1 2.  1.5 0.3 2.1 0.3 2.4 2.4 2.5 2.3 1.  0.4 2.3 1.5 1.3 2.3
#  1.8 0.2 2.3 1.  0.1 1.2 2.  1.3 1.9 1.9 0.2 0.2 0.3 0.2 1.5 1.3 0.2 0.2
#  1.6 1.3 1.7 0.2 0.1 0.2 1.4 1.  1.2 1.3 1.9 0.4 0.2 0.2 1.  1.7 0.2 1.5
#  0.3 1.8 2.1 0.3 0.1 1.8 0.1 1.8 0.2 2.2 2.3 0.4 0.4 2.  1.3 0.3 1.9 0.2
#  1.1 2.2 1.  2.3 1.  1.9 0.2 1.2 0.4 1.5 0.2 1.4 1.4 0.4 2.3 1.  2.3 1.3
#  2.  1.8 1.6 1.8 0.3 2.  1.4 0.2 2.  0.6 1.5]

# %%
print(x_test)
# Out:
# [[125.    6.7   3.3   5.7]
#  [103.    7.1   3.    5.9]
#  [ 23.    4.6   3.6   1. ]
#  [ 53.    6.9   3.1   4.9]
#  [ 66.    6.7   3.1   4.4]
#  [117.    6.5   3.    5.5]
#  [ 84.    6.    2.7   5.1]
#  [ 25.    4.8   3.4   1.9]
#  [ 43.    4.4   3.2   1.3]
#  [  3.    4.7   3.2   1.3]
#  [ 86.    6.    3.4   4.5]
#  [137.    6.3   3.4   5.6]
#  [101.    6.3   3.3   6. ]
#  [118.    7.7   3.8   6.7]
#  [ 97.    5.7   2.9   4.2]
#  [ 35.    4.9   3.1   1.5]
#  [138.    6.4   3.1   5.5]
#  [ 52.    6.4   3.2   4.5]
#  [ 90.    5.5   2.5   4. ]
#  [108.    7.3   2.9   6.3]
#  [120.    6.    2.2   5. ]
#  [ 39.    4.4   3.    1.3]
#  [ 26.    5.    3.    1.6]
#  [ 72.    6.1   2.8   4. ]
#  [ 77.    6.8   2.8   4.8]
#  [ 75.    6.4   2.9   4.3]
#  [ 91.    5.5   2.6   4.4]
#  [ 65.    5.6   2.9   3.6]
#  [  4.    4.6   3.1   1.5]
#  [ 59.    6.6   2.9   4.6]]

# %%
print(y_test)
# Out:
# [2.1 2.1 0.2 1.5 1.4 1.8 1.6 0.2 0.2 0.2 1.6 2.4 2.5 2.2 1.3 0.1 1.8 1.5
#  1.3 1.8 1.5 0.2 0.2 1.3 1.4 1.3 1.2 1.3 0.2 1.3]

# %%
#MODEL:  SVM (SUPPORT VECTOR MACHINE ALGORITHM)

# %%
from sklearn.svm import SVC 
model_svc = SVC()
model_svc.fit(x_train,y_train) #model fitting
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [121], line 3
#       1 from sklearn.svm import SVC
#       2 model_svc = SVC()
# ----> 3 model_svc.fit(x_train,y_train)
#
# File C:\Python 3.10\lib\site-packages\sklearn\svm\_base.py:201, in BaseLibSVM.fit(self, X, y, sample_weight)
#     191 else:
#     192     X, y = self._validate_data(
#     193         X,
#     194         y,
#    (...)
#     198         accept_large_sparse=False,
#     199     )
# --> 201 y = self._validate_targets(y)
#     203 sample_weight = np.asarray(
#     204     [] if sample_weight is None else sample_weight, dtype=np.float64
#     205 )
#     206 solver_type = LIBSVM_IMPL.index(self._impl)
#
# File C:\Python 3.10\lib\site-packages\sklearn\svm\_base.py:745, in BaseSVC._validate_targets(self, y)
#     743 def _validate_targets(self, y):
#     744     y_ = column_or_1d(y, warn=True)
# --> 745     check_classification_targets(y)
#     746     cls, y = np.unique(y_, return_inverse=True)
#     747     self.class_weight_ = compute_class_weight(self.class_weight, classes=cls, y=y_)
#
# File C:\Python 3.10\lib\site-packages\sklearn\utils\multiclass.py:218, in check_classification_targets(y)
#     210 y_type = type_of_target(y, input_name="y")
#     211 if y_type not in [
#     212     "binary",
#     213     "multiclass",
#    (...)
#     216     "multilabel-sequences",
#     217 ]:
# --> 218     raise ValueError("Unknown label type: %r" % y_type)
#
# ValueError: Unknown label type: 'continuous'

# %%
prediction1 = model_svc.predict(x_test)
#To calculate accuracy use accuracy_score
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,prediction1))
